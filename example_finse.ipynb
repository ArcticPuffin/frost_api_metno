# %% [markdown]
# # How to use metno's FROST API

# %% [markdown]
# to be able to use the database, you need your own client_id from metno.

# %%
# import the function to access the data
from frost_function import get_metno_data

# %%
# the following arguments are needed to retrieve data
client_id = 'e799e62a-d405-4f40-ab6d-e111b4677c62'
start = '2010-04-01'
end = '2010-06-01'
voi = 'air_temperature, wind_speed, relative_humidity'
stationID = 'SN25830'

# %%
# ask for data and get a pandas data frame
print('... this may take a while')
df = get_metno_data(stationID, voi, start, end, client_id)
print('...done!')
# Out:
# ... this may take a while

# %%
# a quick look at the data
df.index = pd.to_datetime(df.index)
df.head()
# Out:
#                      air_temperature  relative_humidity  wind_speed
# 2010-04-01 00:00:00             -2.2                 96         8.1
# 2010-04-01 01:00:00             -2.7                100         7.8
# 2010-04-01 02:00:00             -2.7                 94         7.1
# 2010-04-01 03:00:00             -3.5                 94         6.4
# 2010-04-01 04:00:00             -3.8                 96         5.5

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f902ea10cc0>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f902ebadac8>], dtype=object)
